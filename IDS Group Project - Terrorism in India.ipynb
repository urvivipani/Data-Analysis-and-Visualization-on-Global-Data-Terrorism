# %% [markdown]
# <h1><center>Terrorism in India</center></h1>
#
# <center><i>by Vikrant Gaur, Parth Patel, Urvi Vipani</i></center>

# %% [markdown]
# # 1. Executive Summary

# %% [markdown]
# **TBD**
#
# Terrorism is the largest human-oriented criminal organization that has become a common problem globally. Nowadays, it is known that the underlying reason of most of today’s terrorist activities is strategic actions and international purposes. Terrorist attacks in a country can take place because of interior reasons (economic prosperity, socio-cultural, educational system) or other factors. The most important of factor is the geopolitical position of the country.

# %% [markdown]
# # 2. Introduction

# %% [markdown]
# There is no universal agreement on the definition of terrorism. Various legal systems and government agencies around the world have been using different definitions. Moreover, governments have been reluctant to formulate an agreed upon and legally binding definition of Terrorism. This difficulty arises from the fact that the term terrorism is politically and emotionally charged.
#
# Definition of terrorism: “The threatened or actual use of illegal force and violence by a non-state actor to attain a political, economic, religious, or social goal through fear, coercion, or intimidation.”
#
# For our paper, we will be narrowing our scope to India and analyze terrorism activity from 1998 to 2017. The reason for selecting India is mainly based on two main factors: Firstly, due to familiarity with the location and secondly, India being ranked 8th on the list of highest impact by terrorism (Global Terrorism Index, 2017).
#
# From 2002 to 2015 India was ranked between second and sixth on the GTI, though it’s ranking improved in the recent year and its ranked eighth now.  (Global Terrorism Index, 2017). However, despite the decrease in deaths over the last two years, the number of terrorist attacks have increased. There were 16 percent more attacks in 2016 than in 2015(continuing the four-year trend of increasing attacks) (Global Terrorism Index, 2017).
#
# The reminder of the paper will be presented as follows. Section 3 mentions the various objectives of the study. Section 4 describes the data and how it was obtained. Section 5 elaborates on how the data was prepared for our analysis purpose. Section 6 mentions a detailed analysis of each objective. Section 7 discusses the assumptions based on which the models were created, and the analysis was conducted, followed by the conclusion in Section 8.

# %% [markdown]
# # 3. Objective

# %% [markdown]
# The purpose of the paper is to understand Terrorism in India by performing the following analysis:
# 1. Explore GTD data to see trend in terrorist attack
#     - over two decades (1998-2017),
#     - states,
#     - month/season,
#     - place of attack
#     - weapon used,
#     - attack style.
#
# 2. Predict the following based on the given data:
#     - Can casualties be predicted from attack characteristics (e.g., states, attack type, target type, weapon type, etc )?
#
#
# **Why is this imporant?**
#
# Our analysis can depict/show a trend that might occur in the future or that one should be aware of. If we can somehow predict the number of individuals injured (and even dead) due to these incidents (that may occur in the future) then corrective actions can be taken by healthcare professionals, government officials, neighbors in order to help the injured individuals. To minimize future attacks aftermath in terms of providing injured with help as soon as possible.
#
# **Target Audiance**
# 1. Government
# 2. Military & Police
# 3. Private Citizens
# 4. Journalists & Media
# 5. Businesses

# %% [markdown]
# # 4. Data Dictionary

# %% [markdown]
# The **Global Terrorism Database** (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on **domestic** as well as **international** terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks (START, 2018). The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.
#
#
# ## 4.1 Criterias
# Following two out of the three criteria had to be met for inclusion in GTD:
# 1. The violent act was aimed at attaining a political, economic, religious, or social goal;
# 2. The violent act included evidence of an intention to coerce, intimidate, or convey some other message to a larger audience (or audiences) other than the immediate victims; and
# 3. The violent act was outside the precepts of International Humanitarian Law.
#
# ## 4.2 Characteristics
# Characteristics of the GTD data:
# 1. Contains information on over 180,000 terrorist attacks.
# 2. Currently the most comprehensive unclassified database on terrorist attacks in the world.
# 3. Includes information on more than 88,000 bombings, 19,000 assassinations, and 11,000 kidnappings since 1970.
# 4. Includes information on at least 45 variables for each case, with more recent incidents including information on more than 120 variables.
# 5. More than 4,000,000 news articles and 25,000 news sources were reviewed to collect incident data from 1998 to 2017 alone.
#
# ## 4.3 Features
# Necessary information about mostly used fields can be found below. Please refer to the <a href="https://www.start.umd.edu/gtd/downloads/Codebook.pdf">GTD Codebook</a> for definitons on each field and coding schema.
#
# 1. eventid: Incidents from the GTD follow a 12-digit Event ID system.
# 2. iyear: This field contains the year in which the incident occurred.
# 3. imonth: This field contains the number of the month in which the incident occurred.
# 4. iday: This field contains the numeric day of the month on which the incident occurred.
# 5. country: This field identifies the country code country or location where the incident occurred.
# 6. region: This field identifies the region code in which the incident occurred.
# 7. provstate: This variable records the name (at the time of event) of the 1st order subnational administrative region in which the event occurs.
# 8. city: This field contains the name of the city, village, or town in which the incident occurred.
# 9. latitude: This field records the latitude (based on WGS1984 standards) of the city in which the event occurred.
# 10. longitude: This field records the longitude (based on WGS1984 standards) of the city in which the event occurred.
# 11. location: This field is used to specify additional information about the location of the incident.
# 12. success: Success of a terrorist strike is defined according to the tangible effects of the attack. Success is not judged in terms of the larger goals of the perpetrators.

# %% [markdown]
# # 5. Data Preperation

# %% [markdown]
# Summary

# %% [markdown]
# ### 5.1 Importing Libraries

# %%
# Numpy and Pandas
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Prediction
import statsmodels.api as sm
from sklearn.cross_validation import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
import itertools
from sklearn import datasets
from sklearn import linear_model

# Classifiers
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.dummy import DummyClassifier # Validation

# Data prepping
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### 5.2 Loading the GTD raw data

# %%
GTD_data = pd.read_csv('P://Rutgers 2018//subjects//Data Science/final project/GT Dataset.csv', encoding='ISO-8859-1')
# Out:
# C:\Users\patel\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (4,6,33,61,62,63,76,79,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(GTD_data)
# Out:
#              eventid  iyear  imonth  iday       approxdate  extended  \
# 0       199501000001   1995       1     0              NaN         0
# 1       199501000002   1995       1     0              NaN         0
# 2       199501000003   1995       1     0              NaN         0
# 3       199501010001   1995       1     1              NaN         0
# 4       199501010002   1995       1     1              NaN         0
# 5       199501010004   1995       1     1              NaN         0
# 6       199501010005   1995       1     1              NaN         0
# 7       199501010006   1995       1     1              NaN         0
# 8       199501010007   1995       1     1              NaN         0
# 9       199501010009   1995       1     1              NaN         0
# 10      199501010010   1995       1     1              NaN         0
# 11      199501010011   1995       1     1              NaN         0
# 12      199501020001   1995       1     2              NaN         0
# ...

# %%
GTD_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123520 entries, 0 to 123519
# Data columns (total 135 columns):
# eventid               int64
# iyear                 int64
# imonth                int64
# iday                  int64
# approxdate            object
# extended              int64
# resolution            object
# country               int64
# country_txt           object
# region                int64
# region_txt            object
# provstate             object
# city                  object
# latitude              float64
# longitude             float64
# specificity           float64
# vicinity              int64
# location              object
# summary               object
# crit1                 int64
# crit2                 int64
# crit3                 int64
# doubtterr             float64
# alternative           float64
# alternative_txt       object
# multiple              float64
# success               int64
# suicide               int64
# ...

# %% [markdown]
# ### 5.3 Data Cleaning

# %%
GTD_data['ncasualties'] = GTD_data['nkill'] + GTD_data['nwound']
GTD_data['has_casualties'] = GTD_data['ncasualties'].apply(lambda x: 0 if x == 0 else 1)

# %%
data_columns = [
    
        'eventid', # Unique ID alloted to a row,used in Plotting functions.
    
    # Time and Space where the Act of Terrorism committed is defined by the fields above.
        'iyear', 'imonth', 'iday', 'latitude', 'longitude',
    
    # Binary Variables (1 -> Yes or 0 -> no) 
        'extended', # Did the duration of the Incident extend more than 24 hours?
        'vicinity', # Did the Incident occur in the immediate vicinity of the city? 0 is for IN city.
        'crit1', 'crit2', 'crit3', # The Incident meets the criterion (1, 2, 3), described in the introduction.
        'doubt', # Is there any doubt to whether the attack is an act of terrorism?
        'multiple', # Is this incident connected to other incident(s)?
        'success', # Has the attack reached its goal? Depends on type of attack.
        'suicide', # Did the perpetrator intend to escape alive?
        'claimed', # Was the attack claimed by any organised group?
        'property', # Is there any evidence of property damage from the incident?
        'ishostkid', # Were there victims taken as hostage or kidnapped?
    
    # Continuous Variables 
        'nkill', # Amount of confirmed kills.
        'nwound', # Amount of confirmed wounded.
    
    # Categorical Variables 
        'country_txt', # Name of country.
        'region', # Region id.
        'region_txt', # Name of region.
        'attacktype1_txt', # Describing the type of the attack I.e. Assassination, Bombing or Kidnapping.
        'targtype1_txt', # What type of target did the attack have? I.e. business, government or police.
        'natlty1_txt', # Nationality of the target.
        'weaptype1_txt', # What weapon was used?
    
    # Descriptive Variables 
        'target1', # Description of specific target, if applicable.
        'gname', # Name of the organized group, if applicable.
        'summary', # Summary of the attack.
        
    
]

# %% [markdown]
# We can clearly see that the data set is quite large and thus we will have to know about the dimensions of the dataset. We will use the shape command.

# %%
GTD_data.shape
# Out:
# (123520, 137)

# %% [markdown]
# from the output mentioned above, we see that we have around 135 attributes which is way too big to be analysed (isko aise likhna ki apna analysis ke liye 135 is big num)
#
# we now need to realize the attributes from the GTD_data that are important. One way to do is see how much data is null in each attribute. We can do that by the following code

# %%
GTD_data.isnull().sum()
# Out:
# eventid                    0
# iyear                      0
# imonth                     0
# iday                       0
# approxdate            114309
# extended                   0
# resolution            122308
# country                    0
# country_txt                0
# region                     0
# region_txt                 0
# provstate                116
# city                     434
# latitude                1445
# longitude               1445
# specificity                6
# vicinity                   0
# location               68815
# summary                 9260
# crit1                      0
# crit2                      0
# crit3                      0
# doubtterr                  1
# alternative           104008
# alternative_txt       104008
# multiple                   1
# success                    0
# suicide                    0
# attacktype1                0
# attacktype1_txt            0
#                        ...
# propvalue              94518
# ...

# %% [markdown]
# From the above given outputs we can see that

# %%
col1 = ['approxdate','extended','resolution','specificity','vicinity','summary','crit1','crit2','crit3','doubtterr']
col2 = ['alternative','alternative_txt','multiple','suicide','corp1','target1','natlty1','natlty1_txt','targtype2','targtype2_txt']
col3 = ['targsubtype2','targsubtype2_txt','corp2','target2','natlty2','natlty2_txt','targtype3','targsubtype3','targsubtype3_txt','corp3','target3','natlty3','natlty3_txt']
col4 = ['gsubname','gname2','gsubname2','gname3','gsubname3','motive','guncertain1','guncertain2','guncertain3','individual','nperps']
col5 = ['nperpcap','claimed','claimmode','claimmode_txt','claim2','claimmode2','claimmode2_txt','claim3','claimmode3','claimmode3_txt','compclaim','weaptype2','weaptype2_txt','weapsubtype2','weapsubtype2_txt','weaptype3','weaptype3_txt','weapsubtype3','weapsubtype3_txt','weaptype4','weaptype4_txt','weapsubtype4','weapsubtype4_txt','weapdetail']
col6 = ['nkillus','nkillter','nwoundus','nwoundte','propcomment','ishostkid','nhostkid','nhostkidus','nhours','ndays','divert','kidhijcountry','ransom','ransomamt','ransomamtus','ransompaid','ransompaidus','ransomnote','hostkidoutcome','hostkidoutcome_txt','nreleased','addnotes','scite1','scite2','scite3','dbsource','INT_LOG','INT_IDEO','INT_MISC','INT_ANY','related']

drop_col = col1 + col2 + col3 + col4 + col5 + col6

GTD_data.drop(drop_col, inplace = True, axis =1)

GTD_data.shape
# Out:
# (123520, 38)

# %%
print(GTD_data.head())
# Out:
#         eventid  iyear  imonth  iday  country    country_txt  region  \
# 0  199501000001   1995       1     0      217  United States       1
# 1  199501000002   1995       1     0      217  United States       1
# 2  199501000003   1995       1     0      217  United States       1
# 3  199501010001   1995       1     1      202     Tajikistan       7
# 4  199501010002   1995       1     1      209         Turkey      10
#
#                    region_txt   provstate         city      ...        \
# 0               North America  New Mexico  Albuquerque      ...
# 1               North America  New Mexico  Albuquerque      ...
# 2               North America  New Mexico  Albuquerque      ...
# 3                Central Asia    Dushanbe     Dushanbe      ...
# 4  Middle East & North Africa    Istanbul     Istanbul      ...
#
#    weapsubtype1  weapsubtype1_txt nkill  nwound  property propextent  \
# 0           NaN               NaN   0.0     0.0         1        NaN
# ...

# %%
GTD_data = GTD_data.rename(columns={'eventid':'id', 'iyear':'year', 'imonth':'month', 'iday':'day',
             'provstate':'state', 'targtype1_txt':'target',
             'weaptype1_txt':'weapon', 'nkill':'fatalities', 'nwound':'injuries'})

GTD_data
# Out:
#                   id  year  month  day  country               country_txt  \
# 0       199501000001  1995      1    0      217             United States
# 1       199501000002  1995      1    0      217             United States
# 2       199501000003  1995      1    0      217             United States
# 3       199501010001  1995      1    1      202                Tajikistan
# 4       199501010002  1995      1    1      209                    Turkey
# 5       199501010004  1995      1    1       55                   Denmark
# 6       199501010005  1995      1    1       55                   Denmark
# 7       199501010006  1995      1    1       55                   Denmark
# 8       199501010007  1995      1    1       55                   Denmark
# 9       199501010009  1995      1    1       83                 Guatemala
# 10      199501010010  1995      1    1       83                 Guatemala
# 11      199501010011  1995      1    1       83                 Guatemala
# ...

# %%
Ind_terror = GTD_data[(GTD_data.country_txt == 'India')]

Ind_terror
# Out:
#                   id  year  month  day  country country_txt  region  \
# 45      199501070007  1995      1    7       92       India       6
# 91      199501130010  1995      1   13       92       India       6
# 153     199501220007  1995      1   22       92       India       6
# 168     199501240010  1995      1   24       92       India       6
# 182     199501260008  1995      1   26       92       India       6
# 241     199502040008  1995      2    4       92       India       6
# 242     199502040009  1995      2    4       92       India       6
# 243     199502040010  1995      2    4       92       India       6
# 244     199502040011  1995      2    4       92       India       6
# 245     199502040012  1995      2    4       92       India       6
# 250     199502050006  1995      2    5       92       India       6
# 258     199502060008  1995      2    6       92       India       6
# 267     199502080005  1995      2    8       92       India       6
# ...

# %% [markdown]
# # 6. Analysis

# %% [markdown]
# ## 6.1 Exploratory Data Analysis - Global

# %%
# Country wise terrorist attacks (top 20)
country_by_attacks = GTD_data[['country_txt','id']].groupby('country_txt').count()\
.sort_values('id',ascending=0).head(20)
country_by_attacks.plot(kind='bar',legend=False)
plt.xlabel('Country')
plt.ylabel('Attacks')
plt.show()

# %%
barplot = pd.value_counts(GTD_data['year'])\
.sort_index().plot.bar(width=0.8, figsize=(10, 10), color='dodgerblue', title="Amount of Terrorist Attacks Per Year")

# %%
region_dictionary = {1: 'North America', 2: 'Central America & Carribean', 3: 'South America',
                     4: 'East Asia', 5: 'Southeast Asia', 6: 'South Asia', 7: 'Central Asia',
                     8: 'Western Europe', 9: 'Eastern Europe', 10: 'Middle East and North Africa',
                     11: 'Sub-Saharan Africa', 12: 'Australasia and Oceania'}

def multi_graph(result,result_list, xmin, xmax, ymin, ymax):
    fig2, ax2 = plt.subplots(figsize = (15,8))
    number = 1 #the for-loop in append_list processes the regions in order from 1 to 12
    for j in result_list:
        ax2.plot(j.index, j.id, label = '%s ' % region_dictionary[number] )
        number += 1

    plt.xlim([xmin,xmax])
    plt.ylim([ymin,ymax])
    plt.xlabel('year')
    plt.ylabel('number of attacks')
    plt.title(result)
    ax2.legend(loc = 'center', frameon = True, edgecolor = 'black',bbox_to_anchor =(1.2,0.4))


success_list = []
failure_list = []

for i in region_dictionary:
    region_data = GTD_data[(GTD_data.region == i)]
    region_data_success = region_data[(region_data.success == 1)]
    region_data_failure = region_data[(region_data.success == 0)]
    region_grouped_success = region_data_success.groupby('year').count()
    region_grouped_failure = region_data_failure.groupby('year').count()

    
    success_list.append(region_grouped_success)
    failure_list.append(region_grouped_failure)

#multi_graph('Successes',success_list, 2011, 2011, 0, 2100)
multi_graph('Successes',success_list, 2012, 2016, 0, 6500)
#multi_graph('Failures',failure_list, 2011, 2011, 0, 200)
multi_graph('Failures',failure_list, 2012, 2016, 0, 1300)

# %%
plt.figure(figsize=(10,10))
attack = sns.countplot(y="attacktype1_txt", data=GTD_data)
attack.set_xlabel("Amount of attacks")
attack.set_ylabel("Attack type")
# Out:
# Text(0,0.5,'Attack type')

# %% [markdown]
# ## 6.2 Exploratory Data Analysis - India

# %% [markdown]
# ### 6.2.1 Over two decades (1998-2017)

# %%
barplot = pd.value_counts(Ind_terror['year'])\
.sort_index().plot.bar(width=0.8, figsize=(10, 10), color='orange',  title="Amount of Terrorist Attacks in India Per Year")

# %% [markdown]
# ### 6.2.2 States

# %%
barplot = pd.value_counts(Ind_terror['state'])\
.sort_index().plot.bar(width=0.8, figsize=(10, 10), color='orange', title="Amount of Terrorist Attacks in India by states")

# %% [markdown]
# ### 6.2.3 Month/season

# %%
barplot = pd.value_counts(Ind_terror['month'])\
.sort_index().plot.bar(width=0.8, figsize=(10, 10), color='orange', title="Amount of Terrorist Attacks by month")

# %% [markdown]
# ### 6.2.4 Place of attack

# %%
barplot = pd.value_counts(Ind_terror['target'])\
.sort_index().plot.bar(width=0.8, figsize=(10, 10), color='orange', title="Amount of Terrorist Attacks by place")

# %% [markdown]
# ### 6.2.5 Weapon used

# %%
barplot = pd.value_counts(Ind_terror['weapon'])\
.sort_index().plot.bar(width=0.8, figsize=(10, 10), color='orange', title="Amount of Terrorist Attacks by weapon")

# %% [markdown]
# ### 6.2.6 Attack style

# %%
barplot = pd.value_counts(Ind_terror['attacktype1_txt'])\
.sort_index().plot.bar(width=0.8, figsize=(10, 10), color='orange', title="Amount of Terrorist Attacks by attack style")

# %% [markdown]
# ## 6.3 Casualty prediction from attack characteristics

# %%
feature_cols = [
      'year', 'month', 'day', 'latitude', 'longitude',
                'success',
                'property',
                'state',
                'attacktype1_txt',
                'target',
                'weapon',
]

# Target is a binary value: were there any casualties in the attack?
target_col = 'has_casualties'

lb = LabelEncoder()
Ind_terror['country_txt'] = lb.fit_transform(Ind_terror['country_txt'])
Ind_terror['attacktype1_txt'] = lb.fit_transform(Ind_terror['attacktype1_txt'])
Ind_terror['target'] = lb.fit_transform(Ind_terror['target'])
Ind_terror['weapon'] = lb.fit_transform(Ind_terror['weapon'])
Ind_terror['state'] = lb.fit_transform(Ind_terror['state'])

# Define X and Y.
X = Ind_terror[feature_cols].fillna(0)
y = Ind_terror[target_col]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
# Out:
# C:\Users\patel\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\patel\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\patel\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# Build a forest and compute the feature importances
forest = ExtraTreesClassifier(n_estimators=20,
                              random_state=0)

forest.fit(X, y)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]
fnames = [feature_cols[i] for i in indices]

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), fnames, rotation=90)
plt.xlim([-1, X.shape[1]])
plt.show()

# %%
feature_cols = ['longitude', 'latitude', 'target',  'attacktype1_txt', 'success', 'weapon', 'property']

X = Ind_terror[feature_cols].fillna(0) # Assign chosen features to X.

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
model = RandomForestClassifier(n_estimators=20)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

np.mean(y_pred == y_test)
# Out:
# 0.8205304857044436

# %%
cnf_matrix = confusion_matrix(y_test, y_pred)
 

def plot_confusion_matrix(cm,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
 
    print(cm)
 
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
 
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
 
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
 
# Compute confusion matrix
np.set_printoptions(precision=2)
 
# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix,
                      title='Confusion matrix, without normalization')
 
# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, normalize=True,
                      title='Normalized confusion matrix')
 
plt.show()
# Out:
# Confusion matrix, without normalization
# [[ 954  259]
#  [ 262 1428]]
# Normalized confusion matrix
# [[0.79 0.21]
#  [0.16 0.84]]

# %%
# Better validation with K-fold.
model = RandomForestClassifier(n_estimators=20)

scores = cross_val_score(model, X, y, cv=10) # Ten-fold cross validation.
print(scores)
print('Accuracy: %0.2f (+/- %0.2f)' % (scores.mean(), scores.std() * 2))
# Out:
# [0.66 0.81 0.81 0.81 0.78 0.78 0.78 0.81 0.81 0.83]
# Accuracy: 0.79 (+/- 0.09)

# %%
# Simply predict the most frequent value every time.
# This determines the baseline accuracy.
model = DummyClassifier(strategy="most_frequent")

# %time model.fit(X_train, y_train)

# %time y_pred = model.predict(X_test)

np.mean(y_pred == y_test)
# Out:
# Wall time: 1.49 ms
# Wall time: 990 µs
# 0.5821563899414399

# %%
# TITLE

# %%
lm =linear_model.LinearRegression()

feature_cols = ['longitude', 'latitude', 'target',  'attacktype1_txt', 'success', 'weapon', 'property']

x =pd.DataFrame(feature_cols)


y = Ind_terror['injuries']
model = lm.fit(x,y)

model
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-b8c9b9ef1f68> in <module>()
#       7
#       8 y = Ind_terror['injuries']
# ----> 9 model = lm.fit(x,y)
#      10
#      11 model
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %% [markdown]
# # 7. Assumptions

# %% [markdown]
# **TBD**
#
# Terrorist activites not reported in media or newspaper have been exlcuded from this analysis.
#
# Its not based on concrete facts. It is based on

# %% [markdown]
# # 8. Conclusions

# %% [markdown]
# **TBD**
#
# To continue the predictive part of the research, the importance of each column of the terrorism database was estimated using the Random Forest classifier. The resuts were plotted in a bar graph, ordered by accuracy. Time variables such as day, month and year were excluded from features, despite proving to possess high predictive power.
#
# Finally, the best features were chosen and collectively used in a Random Forest classifier. The features included:
#
# Longitude
# Target type,
# Latitude
# Attack type
# Success
# Property (damage)
# Country
# The Random Forest classifier produced an accuracy score of 78%.

# %% [markdown]
# # 9. References

# %% [markdown]
# Cronin, Audrey Kurth. How terrorism ends: understanding the decline and demise of terrorist campaigns. Princeton University Press, 2009.
#
# Global Terrorism Index 2017 - Measuring and understanding the impact of terrorism [PDF]. (2017). The Institute for Economics & Peace.
#
# Max Roser, Mohamed Nagdy and Hannah Ritchie (2018) - "Terrorism". Published online at OurWorldInData.org. Retrieved from: 'https://ourworldindata.org/terrorism' [Online Resource]
#
# National Consortium for the Study of Terrorism and Responses to Terrorism (START). (2018, July 30). Global Terrorism Database. Retrieved November 1, 2018, from https://www.start.umd.edu/gtd/.
